# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import warnings
import time
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import seaborn as sns
#warnings.simplefilter(action='ignore', category=FutureWarning)
# Import API key
from api_keys import api_key
warnings.simplefilter(action='ignore', category=FutureWarning)
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
# create a dataframe
cities_df = pd.DataFrame(cities)
cities_df = cities_df.rename(columns={0:"City"})

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create additional columns to store data from API request
#cities_df['Country'] = ''
cities_df['Longitude'] = ''
cities_df['Latitude'] = ''
cities_df['Date'] = ''
cities_df['Cloudiness'] = ''
cities_df['Temperature Max'] = ''
cities_df['Humidity'] = ''
cities_df['Wind speed'] = ''

# %%
# Create counter
row_count = 1

# loop through cities, make API request, and append desired results
print("Beginning Data Retrieval")
print("------------------------------------------")

# Create a dictionary with parameters to access API
param = {"appid": api_key, "units": "imperial"}

# Base url
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query url
query_url = f"{url}appid={param['appid']}&units={param['units']}&q="


for index, row in cities_df.iterrows():
    city = row["City"]
    
    response = requests.get(query_url + city).json()
    try:
        if response['cod'] != "400":
            cities_df.set_value(index, "Country", response["sys"]["country"]) 
            cities_df.set_value(index,"Longitude", response["coord"]["lon"])
            cities_df.set_value(index, "Latitude", response["coord"]["lat"])
            cities_df.set_value(index, "Date", response['dt'])
            cities_df.set_value(index, "Cloudiness", response["clouds"]["all"])
            cities_df.set_value(index, "Temperature Max", response["main"]["temp_max"])
            cities_df.set_value(index, "Humidity", response["main"]["humidity"])
            cities_df.set_value(index, "Wind speed", response["wind"]["speed"]) 
           
            print(f"Processing Record {row_count} | {city}")
        
            row_count += 1
        else:
            print(f"city not found. Skipping...")
            
            
    #time.sleep(1)
    except (KeyError, IndexError):    
        #print("-------------------------------------------")
        print(f"City not found. Skipping...")
#print("-------------------------------------------")
        #print(f"Retrieving next record")
print("-------------------------------------------")
print(f"Data Retrieval complete")
# Out:
# Beginning Data Retrieval
# ------------------------------------------
# Processing Record 1 | yellowknife
# Processing Record 2 | rikitea
# Processing Record 3 | bluff
# Processing Record 4 | taunggyi
# Processing Record 5 | mataura
# Processing Record 6 | emirdag
# Processing Record 7 | kutum
# Processing Record 8 | karratha
# Processing Record 9 | bredasdorp
# Processing Record 10 | airai
# Processing Record 11 | deputatskiy
# Processing Record 12 | narsaq
# Processing Record 13 | salalah
# Processing Record 14 | qaanaaq
# Processing Record 15 | saint george
# Processing Record 16 | kapaa
# Processing Record 17 | zhigansk
# City not found. Skipping...
# Processing Record 18 | busselton
# Processing Record 19 | upernavik
# Processing Record 20 | hilo
# Processing Record 21 | port alfred
# City not found. Skipping...
# Processing Record 22 | kodiak
# Processing Record 23 | cabo san lucas
# Processing Record 24 | mahebourg
# City not found. Skipping...
# Processing Record 25 | atuona
# Processing Record 26 | namibe
# Processing Record 27 | leesburg
# Processing Record 28 | tessalit
# City not found. Skipping...
# Processing Record 29 | faanui
# Processing Record 30 | punta arenas
# Processing Record 31 | severo-kurilsk
# Processing Record 32 | ushuaia
# City not found. Skipping...
# Processing Record 33 | kapit
# Processing Record 34 | port blair
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 | christchurch
# Processing Record 36 | hobart
# Processing Record 37 | el viejo
# Processing Record 38 | phangnga
# Processing Record 39 | tommot
# Processing Record 40 | georgetown
# Processing Record 41 | albany
# Processing Record 42 | east london
# Processing Record 43 | esperance
# Processing Record 44 | leningradskiy
# Processing Record 45 | ereymentau
# Processing Record 46 | pokhara
# Processing Record 47 | buraydah
# Processing Record 48 | batesville
# Processing Record 49 | tual
# Processing Record 50 | fairbanks
# Processing Record 51 | arawa
# Processing Record 52 | kursenai
# Processing Record 53 | vila velha
# Processing Record 54 | wajima
# Processing Record 55 | los llanos de aridane
# Processing Record 56 | san cristobal
# Processing Record 57 | bethel
# Processing Record 58 | broken hill
# Processing Record 59 | gudibanda
# Processing Record 60 | san carlos de bariloche
# Processing Record 61 | tuktoyaktuk
# Processing Record 62 | darhan
# Processing Record 63 | lebu
# Processing Record 64 | upata
# Processing Record 65 | atasu
# Processing Record 66 | whyalla
# Processing Record 67 | dosso
# Processing Record 68 | barrow
# Processing Record 69 | berlevag
# Processing Record 70 | clyde river
# Processing Record 71 | deloraine
# Processing Record 72 | coihaique
# Processing Record 73 | college
# Processing Record 74 | ostrovnoy
# Processing Record 75 | rehoboth
# Processing Record 76 | rawson
# City not found. Skipping...
# Processing Record 77 | makakilo city
# Processing Record 78 | carnarvon
# Processing Record 79 | new norfolk
# Processing Record 80 | tongchuan
# Processing Record 81 | honningsvag
# Processing Record 82 | springfield
# Processing Record 83 | port elizabeth
# Processing Record 84 | mayo
# Processing Record 85 | puerto ayora
# Processing Record 86 | swan hill
# Processing Record 87 | ixtapa
# City not found. Skipping...
# Processing Record 88 | huilong
# Processing Record 89 | qeshm
# Processing Record 90 | khatanga
# Processing Record 91 | placerville
# City not found. Skipping...
# Processing Record 92 | khash
# Processing Record 93 | santa isabel do rio negro
# Processing Record 94 | sovetskiy
# Processing Record 95 | faya
# City not found. Skipping...
# Processing Record 96 | jamestown
# City not found. Skipping...
# Processing Record 97 | cumaru
# Processing Record 98 | kaitangata
# Processing Record 99 | laem sing
# Processing Record 100 | moree
# Processing Record 101 | ilulissat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 102 | bambous virieux
# Processing Record 103 | mogadishu
# Processing Record 104 | castro
# Processing Record 105 | dimona
# Processing Record 106 | clyde
# Processing Record 107 | cape town
# Processing Record 108 | hermanus
# City not found. Skipping...
# Processing Record 109 | gat
# City not found. Skipping...
# Processing Record 110 | hambantota
# Processing Record 111 | grindavik
# Processing Record 112 | tasiilaq
# Processing Record 113 | saint-philippe
# Processing Record 114 | eyemouth
# Processing Record 115 | dicabisagan
# Processing Record 116 | cherskiy
# City not found. Skipping...
# Processing Record 117 | saint-francois
# Processing Record 118 | hamilton
# City not found. Skipping...
# Processing Record 119 | matiguas
# Processing Record 120 | borshchiv
# Processing Record 121 | tandalti
# Processing Record 122 | klaksvik
# City not found. Skipping...
# Processing Record 123 | dikson
# Processing Record 124 | dakar
# Processing Record 125 | ribeira grande
# Processing Record 126 | cidreira
# Processing Record 127 | norman wells
# Processing Record 128 | lakes entrance
# Processing Record 129 | bayangol
# Processing Record 130 | geraldton
# Processing Record 131 | pacific grove
# Processing Record 132 | simbahan
# Processing Record 133 | souillac
# Processing Record 134 | antofagasta
# Processing Record 135 | provideniya
# Processing Record 136 | lata
# Processing Record 137 | butaritari
# Processing Record 138 | petukhovo
# Processing Record 139 | shimoda
# Processing Record 140 | kortkeros
# Processing Record 141 | san felipe
# Processing Record 142 | sabang
# Processing Record 143 | teya
# Processing Record 144 | moerai
# Processing Record 145 | natal
# Processing Record 146 | jacareacanga
# Processing Record 147 | pizarro
# Processing Record 148 | aripuana
# Processing Record 149 | jishou
# Processing Record 150 | codrington
# Processing Record 151 | kenai
# Processing Record 152 | fortuna
# City not found. Skipping...
# Processing Record 153 | jumla
# Processing Record 154 | churapcha
# Processing Record 155 | tazovskiy
# Processing Record 156 | takab
# Processing Record 157 | turukhansk
# Processing Record 158 | kampot
# Processing Record 159 | cap-aux-meules
# Processing Record 160 | honiara
# Processing Record 161 | muros
# Processing Record 162 | loukhi
# Processing Record 163 | nikolskoye
# Processing Record 164 | pangody
# City not found. Skipping...
# Processing Record 165 | gallup
# Processing Record 166 | tra vinh
# Processing Record 167 | kushima
# City not found. Skipping...
# Processing Record 168 | yumen
# City not found. Skipping...
# Processing Record 169 | vardo
# Processing Record 170 | comodoro rivadavia
# Processing Record 171 | vangaindrano
# Processing Record 172 | mangulile
# Processing Record 173 | inirida
# Processing Record 174 | cadillac
# Processing Record 175 | saldanha
# Processing Record 176 | torbay
# Processing Record 177 | nouadhibou
# Processing Record 178 | iwanai
# Processing Record 179 | xinan
# Processing Record 180 | chatakonda
# Processing Record 181 | jacqueville
# Processing Record 182 | kruisfontein
# Processing Record 183 | alofi
# Processing Record 184 | lagoa
# Processing Record 185 | sao filipe
# Processing Record 186 | helong
# Processing Record 187 | arraial do cabo
# City not found. Skipping...
# Processing Record 188 | ponta do sol
# Processing Record 189 | portland
# Processing Record 190 | hofn
# Processing Record 191 | okhotsk
# Processing Record 192 | havoysund
# Processing Record 193 | krasnoarmeysk
# Processing Record 194 | pevek
# Processing Record 195 | mehamn
# Processing Record 196 | iqaluit
# Processing Record 197 | hasaki
# Processing Record 198 | pitimbu
# Processing Record 199 | odienne
# Processing Record 200 | bawana
# Processing Record 201 | tiksi
# Processing Record 202 | whitianga
# Processing Record 203 | tefe
# Processing Record 204 | sekoma
# Processing Record 205 | cockburn town
# Processing Record 206 | anloga
# Processing Record 207 | isiro
# Processing Record 208 | karpathos
# Processing Record 209 | sao joao da barra
# Processing Record 210 | muzhi
# Processing Record 211 | le havre
# Processing Record 212 | houston
# Processing Record 213 | husavik
# Processing Record 214 | sandpoint
# Processing Record 215 | north bend
# Processing Record 216 | smithers
# Processing Record 217 | nanortalik
# Processing Record 218 | vredendal
# City not found. Skipping...
# Processing Record 219 | vaini
# Processing Record 220 | nerchinsk
# Processing Record 221 | kerrobert
# City not found. Skipping...
# Processing Record 222 | flora
# City not found. Skipping...
# Processing Record 223 | san isidro
# Processing Record 224 | lauro muller
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 225 | mar del plata
# Processing Record 226 | cabedelo
# City not found. Skipping...
# Processing Record 227 | coihueco
# Processing Record 228 | yar-sale
# Processing Record 229 | rio bravo
# Processing Record 230 | diego de almagro
# Processing Record 231 | payo
# Processing Record 232 | tura
# Processing Record 233 | viedma
# Processing Record 234 | manokwari
# Processing Record 235 | careiro da varzea
# Processing Record 236 | pau
# City not found. Skipping...
# Processing Record 237 | lazaro cardenas
# Processing Record 238 | rio gallegos
# Processing Record 239 | komsomolskiy
# Processing Record 240 | romanovo
# Processing Record 241 | oranjemund
# City not found. Skipping...
# Processing Record 242 | torrington
# Processing Record 243 | plouzane
# Processing Record 244 | afsin
# Processing Record 245 | chokurdakh
# Processing Record 246 | kyshtovka
# Processing Record 247 | saint-georges
# Processing Record 248 | filadelfia
# Processing Record 249 | san patricio
# Processing Record 250 | ulladulla
# Processing Record 251 | seoni malwa
# Processing Record 252 | rio grande
# Processing Record 253 | hithadhoo
# Processing Record 254 | espinosa
# Processing Record 255 | thompson
# City not found. Skipping...
# Processing Record 256 | vila franca do campo
# Processing Record 257 | chimore
# Processing Record 258 | adrar
# Processing Record 259 | mancora
# Processing Record 260 | bubaque
# Processing Record 261 | nador
# Processing Record 262 | dudinka
# Processing Record 263 | kaeo
# Processing Record 264 | matata
# Processing Record 265 | fort william
# Processing Record 266 | tuatapere
# Processing Record 267 | hovd
# Processing Record 268 | colatina
# Processing Record 269 | itarema
# Processing Record 270 | ancud
# Processing Record 271 | nabire
# Processing Record 272 | sylvan lake
# Processing Record 273 | port macquarie
# Processing Record 274 | moron
# Processing Record 275 | gaggenau
# Processing Record 276 | abha
# Processing Record 277 | birobidzhan
# Processing Record 278 | roma
# Processing Record 279 | vanimo
# City not found. Skipping...
# Processing Record 280 | yerbogachen
# Processing Record 281 | ghatampur
# Processing Record 282 | longyearbyen
# Processing Record 283 | gashua
# Processing Record 284 | custoias
# Processing Record 285 | ondjiva
# Processing Record 286 | hami
# Processing Record 287 | suntar
# Processing Record 288 | tayu
# Processing Record 289 | ostersund
# Processing Record 290 | kuching
# Processing Record 291 | bowmore
# City not found. Skipping...
# Processing Record 292 | hervey bay
# Processing Record 293 | harper
# Processing Record 294 | dryden
# Processing Record 295 | bima
# Processing Record 296 | mikhaylovka
# Processing Record 297 | ziarat
# Processing Record 298 | macultepec
# Processing Record 299 | agbor
# Processing Record 300 | nioro
# City not found. Skipping...
# Processing Record 301 | matara
# Processing Record 302 | zhezkazgan
# Processing Record 303 | funadhoo
# Processing Record 304 | burnie
# Processing Record 305 | port-cartier
# City not found. Skipping...
# Processing Record 306 | pisco
# Processing Record 307 | baykit
# Processing Record 308 | purificacion
# Processing Record 309 | marsa matruh
# City not found. Skipping...
# Processing Record 310 | marmato
# Processing Record 311 | richards bay
# Processing Record 312 | shache
# City not found. Skipping...
# Processing Record 313 | port hueneme
# City not found. Skipping...
# Processing Record 314 | antsohihy
# Processing Record 315 | buchanan
# Processing Record 316 | luderitz
# Processing Record 317 | guerrero negro
# Processing Record 318 | lillooet
# Processing Record 319 | san andres
# City not found. Skipping...
# Processing Record 320 | ahipara
# Processing Record 321 | aasiaat
# Processing Record 322 | svetlaya
# Processing Record 323 | erzin
# City not found. Skipping...
# Processing Record 324 | atraulia
# Processing Record 325 | santa maria
# Processing Record 326 | kurumkan
# Processing Record 327 | luanda
# Processing Record 328 | westport
# Processing Record 329 | tineo
# Processing Record 330 | griffith
# Processing Record 331 | bereda
# City not found. Skipping...
# Processing Record 332 | saskylakh
# Processing Record 333 | havelock
# Processing Record 334 | lasa
# Processing Record 335 | papetoai
# Processing Record 336 | nuuk
# Processing Record 337 | dingle
# Processing Record 338 | kahului
# Processing Record 339 | seymchan
# Processing Record 340 | rafai
# Processing Record 341 | ambulu
# Processing Record 342 | kalmunai
# Processing Record 343 | port-gentil
# Processing Record 344 | cayenne
# Processing Record 345 | vallenar
# Processing Record 346 | kuragino
# Processing Record 347 | constitucion
# Processing Record 348 | avarua
# Processing Record 349 | verkhnyaya toyma
# Processing Record 350 | abu kamal
# Processing Record 351 | nsanje
# Processing Record 352 | araouane
# Processing Record 353 | mandalgovi
# Processing Record 354 | santa isabel
# Processing Record 355 | severodvinsk
# Processing Record 356 | maragogi
# Processing Record 357 | chiredzi
# Processing Record 358 | novoomskiy
# Processing Record 359 | bathsheba
# Processing Record 360 | bambanglipuro
# Processing Record 361 | camp verde
# Processing Record 362 | semporna
# Processing Record 363 | new baltimore
# Processing Record 364 | mackay
# Processing Record 365 | puerto baquerizo moreno
# Processing Record 366 | krasnokamensk
# Processing Record 367 | port lincoln
# Processing Record 368 | mackenzie
# Processing Record 369 | maldonado
# City not found. Skipping...
# Processing Record 370 | flinders
# Processing Record 371 | slidell
# City not found. Skipping...
# Processing Record 372 | pokrovskoye
# City not found. Skipping...
# Processing Record 373 | zhigalovo
# Processing Record 374 | kavieng
# Processing Record 375 | virginia beach
# Processing Record 376 | acapulco
# Processing Record 377 | la ronge
# Processing Record 378 | umea
# Processing Record 379 | ban nahin
# Processing Record 380 | fuxin
# Processing Record 381 | bodden town
# Processing Record 382 | xuddur
# Processing Record 383 | jalu
# Processing Record 384 | chapais
# Processing Record 385 | kavaratti
# Processing Record 386 | khandbari
# Processing Record 387 | albanel
# City not found. Skipping...
# Processing Record 388 | yokadouma
# Processing Record 389 | manturovo
# Processing Record 390 | srednekolymsk
# Processing Record 391 | cine
# Processing Record 392 | kaduna
# Processing Record 393 | hobyo
# Processing Record 394 | trairi
# Processing Record 395 | kudahuvadhoo
# Processing Record 396 | anadyr
# Processing Record 397 | bemidji
# Processing Record 398 | khanpur
# Processing Record 399 | gairo
# Processing Record 400 | hamada
# Processing Record 401 | mount isa
# Processing Record 402 | oktyabrskiy
# Processing Record 403 | aksarka
# Processing Record 404 | port hardy
# Processing Record 405 | ziro
# Processing Record 406 | kars
# Processing Record 407 | mahina
# Processing Record 408 | muroto
# Processing Record 409 | juli
# Processing Record 410 | sisimiut
# City not found. Skipping...
# Processing Record 411 | awjilah
# Processing Record 412 | shatrovo
# Processing Record 413 | meadow lake
# Processing Record 414 | omboue
# Processing Record 415 | san jose
# Processing Record 416 | soja
# Processing Record 417 | olinda
# Processing Record 418 | muncar
# Processing Record 419 | talnakh
# Processing Record 420 | fukue
# Processing Record 421 | owosso
# Processing Record 422 | padang
# Processing Record 423 | mount gambier
# Processing Record 424 | bandarbeyla
# Processing Record 425 | barra do garcas
# City not found. Skipping...
# Processing Record 426 | canavieiras
# Processing Record 427 | victoria
# City not found. Skipping...
# Processing Record 428 | tsuyama
# Processing Record 429 | goderich
# City not found. Skipping...
# Processing Record 430 | chuy
# Processing Record 431 | miri
# Processing Record 432 | muramatsu
# Processing Record 433 | coquimbo
# Processing Record 434 | lompoc
# Processing Record 435 | corbelia
# Processing Record 436 | tangshan
# Processing Record 437 | tikrit
# Processing Record 438 | fort nelson
# Processing Record 439 | avera
# Processing Record 440 | altus
# Processing Record 441 | antalaha
# Processing Record 442 | pahalgam
# Processing Record 443 | kloulklubed
# Processing Record 444 | grafton
# Processing Record 445 | caravelas
# Processing Record 446 | necochea
# Processing Record 447 | labuhan
# Processing Record 448 | santa cruz
# Processing Record 449 | wanning
# Processing Record 450 | thinadhoo
# Processing Record 451 | platanos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 452 | petropavlovsk-kamchatskiy
# Processing Record 453 | isangel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 454 | gizo
# Processing Record 455 | ulagan
# Processing Record 456 | kiruna
# Processing Record 457 | lavrentiya
# Processing Record 458 | mitu
# City not found. Skipping...
# Processing Record 459 | voh
# Processing Record 460 | hailar
# Processing Record 461 | hazorasp
# Processing Record 462 | vestmannaeyjar
# Processing Record 463 | winnemucca
# Processing Record 464 | garowe
# Processing Record 465 | grand-santi
# Processing Record 466 | coos bay
# Processing Record 467 | chitral
# Processing Record 468 | massaguet
# Processing Record 469 | santa rosa
# Processing Record 470 | mildura
# Processing Record 471 | saint anthony
# Processing Record 472 | shenjiamen
# Processing Record 473 | sitka
# Processing Record 474 | ternate
# Processing Record 475 | alice springs
# Processing Record 476 | pangnirtung
# Processing Record 477 | sioux lookout
# City not found. Skipping...
# Processing Record 478 | massakory
# Processing Record 479 | mitsamiouli
# Processing Record 480 | bhan
# Processing Record 481 | sinnamary
# Processing Record 482 | rapar
# Processing Record 483 | beloha
# Processing Record 484 | la asuncion
# City not found. Skipping...
# Processing Record 485 | truckee
# Processing Record 486 | toledo
# Processing Record 487 | kaa-khem
# City not found. Skipping...
# Processing Record 488 | san cayetano
# Processing Record 489 | agadir
# Processing Record 490 | bolobo
# Processing Record 491 | tigil
# Processing Record 492 | buala
# Processing Record 493 | ambilobe
# Processing Record 494 | port hedland
# Processing Record 495 | salmo
# Processing Record 496 | sept-iles
# Processing Record 497 | moose jaw
# Processing Record 498 | hudson bay
# Processing Record 499 | divnoye
# Processing Record 500 | basoko
# Processing Record 501 | tougue
# Processing Record 502 | nemuro
# Processing Record 503 | virovitica
# Processing Record 504 | bundaberg
# Processing Record 505 | vieux-habitants
# Processing Record 506 | tabou
# Processing Record 507 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 508 | lufilufi
# Processing Record 509 | savantvadi
# Processing Record 510 | yarim
# Processing Record 511 | belmopan
# Processing Record 512 | nenjiang
# Processing Record 513 | agirish
# Processing Record 514 | kargasok
# Processing Record 515 | dzilam gonzalez
# Processing Record 516 | prince rupert
# Processing Record 517 | ibra
# Processing Record 518 | sandovo
# Processing Record 519 | mareeba
# Processing Record 520 | troitskoye
# Processing Record 521 | totma
# City not found. Skipping...
# Processing Record 522 | lenoir
# Processing Record 523 | gazojak
# Processing Record 524 | turayf
# Processing Record 525 | bonfim
# City not found. Skipping...
# Processing Record 526 | beringovskiy
# City not found. Skipping...
# Processing Record 527 | tarata
# Processing Record 528 | brae
# Processing Record 529 | miandrivazo
# Processing Record 530 | duku
# Processing Record 531 | atar
# Processing Record 532 | porto novo
# Processing Record 533 | ventspils
# Processing Record 534 | vanavara
# Processing Record 535 | axim
# Processing Record 536 | evensk
# Processing Record 537 | birjand
# Processing Record 538 | severo-yeniseyskiy
# Processing Record 539 | lalsk
# Processing Record 540 | sayyan
# Processing Record 541 | karasjok
# Processing Record 542 | prainha
# Processing Record 543 | high rock
# City not found. Skipping...
# Processing Record 544 | shubarshi
# Processing Record 545 | price
# Processing Record 546 | olden
# Processing Record 547 | chuka
# Processing Record 548 | bilibino
# Processing Record 549 | marawi
# Processing Record 550 | mulege
# Processing Record 551 | luena
# Processing Record 552 | guangyuan
# Processing Record 553 | ede
# Processing Record 554 | saint-pierre
# Processing Record 555 | sao felix do xingu
# Processing Record 556 | oussouye
# Processing Record 557 | hay river
# Processing Record 558 | horki
# Processing Record 559 | sumbe
# Processing Record 560 | yuxia
# -------------------------------------------
# Data Retrieval complete

# %%
cities_df.head()
# Out:
#           City Longitude Latitude        Date Cloudiness Temperature Max  \
# 0  yellowknife   -114.38    62.45  1552788044         20              25
# 1      rikitea   -134.97   -23.12  1552788231         80           77.76
# 2        bluff    149.07   -23.58  1552788266         68           74.03
# 3     taunggyi     97.03    20.78  1552788439          0           79.74
# 4      mataura    168.86   -46.19  1552788008         24              64
#
#   Humidity Wind speed Country
# 0       67      11.41      CA
# 1      100      24.72      PF
# 2      100        5.7      AU
# 3       43        2.8      MM
# 4       73       2.13      NZ

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.count()
# Out:
# City               624
# Longitude          624
# Latitude           624
# Date               624
# Cloudiness         624
# Temperature Max    624
# Humidity           624
# Wind speed         624
# Country            560
# dtype: int64

# %%
cities_df[["Latitude", "Temperature Max"]] = cities_df[["Latitude", "Temperature Max"]].apply(pd.to_numeric, errors='coerce')

# %%
cities_df.head()
# Out:
#           City Longitude  Latitude        Date Cloudiness  Temperature Max  \
# 0  yellowknife   -114.38     62.45  1552788044         20            25.00
# 1      rikitea   -134.97    -23.12  1552788231         80            77.76
# 2        bluff    149.07    -23.58  1552788266         68            74.03
# 3     taunggyi     97.03     20.78  1552788439          0            79.74
# 4      mataura    168.86    -46.19  1552788008         24            64.00
#
#   Humidity Wind speed Country
# 0       67      11.41      CA
# 1      100      24.72      PF
# 2      100        5.7      AU
# 3       43        2.8      MM
# 4       73       2.13      NZ

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build a scatter plot for Latitude vs. Temperature

plt.scatter(cities_df["Latitude"], 
            cities_df["Temperature Max"], edgecolor="black", linewidths=1, marker="o",\
            cmap='plasma', alpha=0.8, label="City")

#Incorporate the other graph properties

plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature ({datetime.now().strftime('%m/%d/%Y')})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
# plt.ylim([-60, 120])


# plt.ylim([-60, 120])

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cities_df["Humidity"] = cities_df["Humidity"].apply(pd.to_numeric, errors='coerce')


#Build a scatter plot for Latitude vs. Humidity

plt.scatter(cities_df["Latitude"], 
            cities_df["Humidity"], edgecolor="black", linewidths=1, marker="o",\
            cmap='plasma', alpha=0.8, label="City")


#Incorporate the other graph properties

plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity ({datetime.now().strftime('%m/%d/%Y')})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
# plt.ylim([-60, 120])

# Save the figure
plt.savefig("Latitude_Humidity.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cities_df ["Cloudiness"]= cities_df["Cloudiness"].apply(pd.to_numeric, errors='coerce')
#Build a scatter plot for Latitude vs. Cloudiness (%)

plt.scatter(cities_df["Latitude"], 
            cities_df["Cloudiness"], c=cities_df["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")


# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness (%) ({datetime.now().strftime('%m/%d/%Y')})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
#plt.ylim([-10, 125])

# Save the figure
plt.savefig("Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cities_df ["Wind speed"]= cities_df["Wind speed"].apply(pd.to_numeric, errors='coerce')

#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(cities_df["Latitude"], 
            cities_df["Wind speed"], c=cities_df["Wind speed"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed (mph) ({datetime.now().strftime('%m/%d/%Y')})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
#plt.ylim([-10, 50])

#plt.ylim([-10, 50])

# Save the figure
plt.savefig("Latitude_WindSpeed.png")


# Show plot
plt.show()
